# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
# %matplotlib inline

# %% [markdown]
# # Cycle for Data Anaylsis
# 1. identify the business problem
# 2. identify datasources
# 3. Select the data
# 4. Clean the data
# 5. Transform the data
# 6. Analysis the data
# 7. interpret,evaluate and deploy the model

# %%
#load excel file
df = pd.read_excel(r"C:\Users\user\Downloads\Dataset\Online Retail.xlsx",encoding="unicode_escape")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#2nd way to load a any dataset
filepath = r"C:\Users\user\Downloads\Dataset"
filename = "Online Retail.xlsx"
dk = pd.read_excel(os.path.join(filepath,filename),encoding="unicode_escape")

# %%
dk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.shape
# Out:
# (541909, 8)

# %%
df["Country"].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
#df.isnull().sum()                  #find null value in the dataset
missing_df = pd.DataFrame(df.isnull().sum(),columns=["Missing_Rows"])    #convert series into dataframe
missing_df["missing_values %"] = missing_df["Missing_Rows"]*100/df.shape[0]  
missing_df["missing_values %"] = round(missing_df["missing_values %"],2)
missing_df = missing_df.sort_values("missing_values %",ascending=False)
missing_df
# Out:
#              Missing_Rows  missing_values %
# CustomerID         135080             24.93
# Description          1454              0.27
# InvoiceNo               0              0.00
# StockCode               0              0.00
# Quantity                0              0.00
# InvoiceDate             0              0.00
# UnitPrice               0              0.00
# Country                 0              0.00

# %%
#make a copy of data
df_2=df.copy()

# %%
df_2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#drop na values
df_2=df_2.dropna(subset=['CustomerID'])

# %%
df_2.shape
# Out:
# (406829, 8)

# %%
df_2.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
#check duplicate rows
df_2_duplicate = df_2[df_2.duplicated(keep=False)]

# %%
df_2_duplicate
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 485       536409     22111      SCOTTIE DOG HOT WATER BOTTLE         1
# 489       536409     22866     HAND WARMER SCOTTY DOG DESIGN         1
# 494       536409     21866       UNION JACK FLAG LUGGAGE TAG         1
# 517       536409     21866       UNION JACK FLAG LUGGAGE TAG         1
# 521       536409     22900   SET 2 TEA TOWELS I LOVE LONDON          1
# ...          ...       ...                               ...       ...
# 541675    581538     22068       BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318    BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992            REVOLVER WOODEN RULER          1
# 541699    581538     22694                      WICKER STAR          1
# 541701    581538     23343      JUMBO BAG VINTAGE CHRISTMAS          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#crosscheck row is either duplicate or not ??
check_df = df_2_duplicate[(df_2_duplicate["StockCode"]==22111) & (df_2_duplicate["InvoiceNo"]==536409)]

# %%
check_df
# Out:
#     InvoiceNo StockCode                   Description  Quantity  \
# 485    536409     22111  SCOTTIE DOG HOT WATER BOTTLE         1
# 539    536409     22111  SCOTTIE DOG HOT WATER BOTTLE         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 485 2010-12-01 11:45:00       4.95     17908.0  United Kingdom
# 539 2010-12-01 11:45:00       4.95     17908.0  United Kingdom

# %%
#drop duplicate data and create new variable for the data
df_3 = df_2.drop_duplicates(keep="first")

# %%
df_3.shape
# Out:
# (401604, 8)

# %%
max(df_2["UnitPrice"])
# Out:
# 38970.0

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.6+ MB

# %%
df_4=df_3.copy()
df_4["CustomerID"] = df_4["CustomerID"].astype(int).astype(str)

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  object
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 27.6+ MB

# %%
df_4.shape
# Out:
# (401604, 8)

# %% [markdown]
# # Convert and combine multiple columns in string

# %%
str_columns = ["InvoiceNo", "StockCode", "Description","Country"]
df_4[str_columns] = df_4[str_columns].astype(str)

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  object
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 27.6+ MB

# %%
int_cols = ["Quantity"]
df_4[int_cols] = df_4[int_cols].astype(int)

# %%
df_4.describe()
# Out:
#             Quantity      UnitPrice
# count  401604.000000  401604.000000
# mean       12.183273       3.474064
# std       250.283037      69.764035
# min    -80995.000000       0.000000
# 25%         2.000000       1.250000
# 50%         5.000000       1.950000
# 75%        12.000000       3.750000
# max     80995.000000   38970.000000

# %%
sns.boxplot(df["Quantity"],orient="v",showmeans=True)

# %%
#multiple boxplot using for loop
cols = ["Quantity","UnitPrice"]
for col in cols:
    sns.boxplot(df_4[col],showmeans=True, orient="v")
    plt.show()

# %%
neg_qty=df_4[df_4["Quantity"]<0]
len(neg_qty)
# Out:
# 8872

# %%
print("% of Neg_qty data :",format(round(8872*100/401604,2)))
# Out:
# % of Neg_qty data : 2.21

# %%
df_4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
#data InvoiceNo starting with letter C
df_4[df_4["InvoiceNo"].str.contains("C")].shape
# Out:
# (8872, 8)

# %%
df_5  = df_4[df_4["Quantity"]>0]
df_6 = df_5[df_5["UnitPrice"]>0]

# %%
df_5.shape
df_6.shape
# Out:
# (392692, 8)

# %%
df_6[df_6["UnitPrice"]>5000]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 173382    551697      POST     POSTAGE         1 2011-05-03 13:46:00
#
#         UnitPrice CustomerID         Country
# 173382    8142.75      16029  United Kingdom

# %%
cols = ["Quantity","UnitPrice"]
for col in cols:
    sns.boxplot(df_6[col],showmeans=True, orient="v")
    plt.show()

# %%
data_check = df_6[df_6["StockCode"]=="POST"]
data_check
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 45        536370      POST     POSTAGE         3 2010-12-01 08:45:00
# 386       536403      POST     POSTAGE         1 2010-12-01 11:27:00
# 1123      536527      POST     POSTAGE         1 2010-12-01 13:04:00
# 5073      536840      POST     POSTAGE         1 2010-12-02 18:27:00
# 5258      536852      POST     POSTAGE         1 2010-12-03 09:51:00
# ...          ...       ...         ...       ...                 ...
# 541198    581493      POST     POSTAGE         1 2011-12-09 10:10:00
# 541216    581494      POST     POSTAGE         2 2011-12-09 10:13:00
# 541730    581570      POST     POSTAGE         1 2011-12-09 11:59:00
# 541767    581574      POST     POSTAGE         2 2011-12-09 12:09:00
# 541768    581578      POST     POSTAGE         3 2011-12-09 12:16:00
#
#         UnitPrice CustomerID      Country
# 45           18.0      12583       France
# 386          15.0      12791  Netherlands
# ...

# %%
data_check["UnitPrice"].median()
# Out:
# 18.0

# %%
plt.figure(figsize=(15,5))
plt.plot(data_check["InvoiceDate"],data_check["UnitPrice"])
plt.grid()

# %%
df_6[(df_6["StockCode"]== "POST") & (df_6["CustomerID"]=="16029")]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 173382    551697      POST     POSTAGE         1 2011-05-03 13:46:00
#
#         UnitPrice CustomerID         Country
# 173382    8142.75      16029  United Kingdom

# %%
df_7=df_6.copy()

# %%
df_7.shape
# Out:
# (392692, 8)

# %%
data_check=df_6[(df_6["StockCode"]=="POST")]
df_7["UnitPrice"] = np.where((df_7["UnitPrice"]>2000) & (df_7["StockCode"]=="POST"),
                            data_check["UnitPrice"].median(),
                            df_7["UnitPrice"])

# %%
df_7[(df_7["StockCode"]== "POST") & (df_7["CustomerID"]=="16029")]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 173382    551697      POST     POSTAGE         1 2011-05-03 13:46:00
#
#         UnitPrice CustomerID         Country
# 173382       18.0      16029  United Kingdom

# %%
sns.boxplot(df_7["UnitPrice"],showmeans=True, orient="v")

# %%
df_8 = df_7.copy()
df_8["Amount"] = df_8["Quantity"]*df_8["UnitPrice"]
df_8.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34

# %%
bar_df = pd.DataFrame(df_8.groupby(["Country"])["InvoiceNo"].nunique())
bar_df.head()
# Out:
#            InvoiceNo
# Country
# Australia         57
# Austria           17
# Bahrain            2
# Belgium           98
# Brazil             1

# %%
bar_df = bar_df.rename(columns={"InvoiceNo":"Counts of Orders"})
bar_df = bar_df.sort_values("Counts of Orders",ascending=False)
bar_df.head()
# Out:
#                 Counts of Orders
# Country
# United Kingdom             16646
# Germany                      457
# France                       389
# EIRE                         260
# Belgium                       98

# %%
plt.figure(figsize=(10,7))
sns.barplot(x="Counts of Orders",y=bar_df.index,data=bar_df)
plt.grid()

# %%
#find percent of orders only for UK
uk_count = 16646
total=bar_df["Counts of Orders"].sum()
percent = uk_count*100/total
percent
# Out:
# 89.82300884955752

# %%
#2nd way to find percent of orders only for UK
uk_orders = df_8[df_8["Country"]=="United Kingdom"]["InvoiceNo"].nunique()
uk_orders
Total = df_8["InvoiceNo"].nunique() 
Total
percent = uk_orders*100/Total
print("UK Orders : ",uk_orders)
print("Total Orders : ",Total)
print("Percent of UK Orders : ", round(percent,2))
# Out:
# UK Orders :  16646
# Total Orders :  18532
# Percent of UK Orders :  89.82

# %%
df_8.shape
# Out:
# (392692, 9)

# %%
bar_df["% relative Freq"] = round(bar_df["Counts of Orders"]*100/Total,2)
bar_df = bar_df.sort_values("Counts of Orders",ascending=False)
bar_df.head()
# Out:
#                 Counts of Orders  % relative Freq
# Country
# United Kingdom             16646            89.82
# Germany                      457             2.47
# France                       389             2.10
# EIRE                         260             1.40
# Belgium                       98             0.53

# %%
bar_df["% Cummulative Relative"] = bar_df["% relative Freq"].cumsum()
bar_df.head()
# Out:
#                 Counts of Orders  % relative Freq  % Cummulative Relative
# Country
# United Kingdom             16646            89.82                   89.82
# Germany                      457             2.47                   92.29
# France                       389             2.10                   94.39
# EIRE                         260             1.40                   95.79
# Belgium                       98             0.53                   96.32

# %%
plt.figure(figsize=(18,5))
sns.barplot(x=bar_df.index,y="% relative Freq",data=bar_df)
plt.plot(bar_df["% Cummulative Relative"],ls="--",color="green")
#y-axis

plt.ylim(0,110)
#y-axis space 10 range0 to 110
plt.yticks(np.arange(0,110,10))
#x-axis
# a horizontal line at 95
plt.axhline(95,color="red")
#rotate x-axis country name 90 degree 
plt.xticks(rotation=90,fontsize=13)

plt.title("Numbers of Orders per Country",fontsize=13)
plt.text(30,88,"Covering 95% of Business",fontsize=13)
plt.grid()

# %%
#Bar plot without UK
bar_df_nonUK = bar_df[1:]
plt.figure(figsize=(18,5))
sns.barplot(x=bar_df_nonUK.index,y="% relative Freq",data=bar_df_nonUK)
#rotate x-axis country name 90 degree 
plt.xticks(rotation=90,fontsize=13)

plt.title("Numbers of Orders per Country except UK",fontsize=13)
plt.grid()

# %%
#select random country
bar_df[(bar_df.index=="Germany") | (bar_df.index=="EIRE") | (bar_df.index=="Cyprus")]
# Out:
#          Counts of Orders  % relative Freq  % Cummulative Relative
# Country
# Germany               457             2.47                   92.29
# EIRE                  260             1.40                   95.79
# Cyprus                 16             0.09                   99.65

# %%
#another way any remove 
bar_df[(bar_df.index!="Germany")].head()
# Out:
#                 Counts of Orders  % relative Freq  % Cummulative Relative
# Country
# United Kingdom             16646            89.82                   89.82
# France                       389             2.10                   94.39
# EIRE                         260             1.40                   95.79
# Belgium                       98             0.53                   96.32
# Netherlands                   94             0.51                   96.83

# %%
bar_df.reset_index()[15:].head()
# Out:
#     Country  Counts of Orders  % relative Freq  % Cummulative Relative
# 15   Poland                19             0.10                   99.27
# 16    Japan                19             0.10                   99.37
# 17  Denmark                18             0.10                   99.47
# 18  Austria                17             0.09                   99.56
# 19   Cyprus                16             0.09                   99.65

# %%
df_8
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country  Amount
# ...

# %%
bar_df_Amount = pd.DataFrame(df_8.groupby(["Country"])["Amount"].mean())
bar_df_Amount = bar_df_Amount.rename(columns = {"Amount":"Amount as per Country"})
bar_df_Amount = bar_df_Amount.sort_values("Amount as per Country",ascending=False)
bar_df_Amount.head()
# Out:
#              Amount as per Country
# Country
# Netherlands             121.003111
# Australia               117.234386
# Japan                   116.561900
# Singapore                95.852658
# Sweden                   85.261844

# %%
#barplot as per amount and country
plt.figure(figsize=(15,7))
sns.barplot(x=bar_df_Amount.index,y="Amount as per Country",data=bar_df_Amount)
plt.xticks(rotation=90,fontsize=13)
plt.title("Average Amount per Country",fontsize=13)
plt.grid()
# as per plot netherlands have max avg but in order uk have max order.

# %%
df_9=df_8.copy()

# %%
df_9['Date'] = df_9['InvoiceDate'].dt.date
#same for year and hrs
df_9['Year'] = df_9['InvoiceDate'].dt.year
#delete a columns
#df_9 = df_9.drop(["Date","Hours"],axis=1)

# %%
df_9.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
#
#          Date  Year
# 0  2010-12-01  2010
# 1  2010-12-01  2010
# 2  2010-12-01  2010
# 3  2010-12-01  2010
# 4  2010-12-01  2010

# %%
# Column date is in object(string) format 
df_9['Date'].dtype
# Out:
# dtype('O')

# %%
#convert column Date dtype into datetime dtype
df_9['Date']=pd.to_datetime(df_9["Date"])

# %%
df_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392692 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    392692 non-null  object
#  1   StockCode    392692 non-null  object
#  2   Description  392692 non-null  object
#  3   Quantity     392692 non-null  int32
#  4   InvoiceDate  392692 non-null  datetime64[ns]
#  5   UnitPrice    392692 non-null  float64
#  6   CustomerID   392692 non-null  object
#  7   Country      392692 non-null  object
#  8   Amount       392692 non-null  float64
#  9   Date         392692 non-null  datetime64[ns]
#  10  Year         392692 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int32(1), int64(1), object(5)
# memory usage: 34.5+ MB

# %%
#check data year range
df_9['Year'].unique()
# Out:
# array([2010, 2011], dtype=int64)

# %%
#add new 3 column for month and year,Day,Hours
df_9["Year-Month"] = df_9["InvoiceDate"].dt.strftime('%Y%m')
df_9["Day"] = df_9["InvoiceDate"].dt.strftime('%A')
df_9["Hours"] = df_9["InvoiceDate"].dt.strftime('%H')
#can use as 
#df_9["Hours"] = df_9["InvoiceDate"].dt.hour

# %%
df_9.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
#
#         Date  Year Year-Month        Day Hours
# 0 2010-12-01  2010     201012  Wednesday    08
# ...

# %%
#check ranodmly any row
df_9[58:59]
# Out:
#    InvoiceNo StockCode                        Description  Quantity  \
# 58    536373     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
#
#            InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 58 2010-12-01 09:02:00       6.95      17850  United Kingdom    27.8
#
#          Date  Year Year-Month        Day Hours
# 58 2010-12-01  2010     201012  Wednesday    09

# %%
# get the sales for month -year and plot a graph
month_sale = pd.DataFrame(df_9.groupby('Year-Month')['InvoiceNo'].nunique())
month_sale = month_sale.sort_values('InvoiceNo',ascending=False)
month_sale.head()
# Out:
#             InvoiceNo
# Year-Month
# 201111           2657
# 201110           1929
# 201109           1755
# 201105           1555
# 201012           1400

# %%
plt.figure(figsize=(18,5))
sns.barplot(x=month_sale.index, y='InvoiceNo',data=month_sale)
plt.title("sales-invoices as per month-year")
plt.grid()

# %%
#sales as per day
day_sale = pd.DataFrame(df_9.groupby("Day")["InvoiceNo"].nunique())
# for just a format mon to sun
day_sale.index = pd.Categorical(day_sale.index,
                                categories=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
                                ordered=True)
day_sale
# Out:
#            InvoiceNo
# Friday          2829
# Monday          2863
# Sunday          2169
# Thursday        4032
# Tuesday         3184
# Wednesday       3455

# %%
plt.figure(figsize=(13,7))
sns.barplot(x=day_sale.index, y="InvoiceNo", data=day_sale)
plt.grid()
plt.title("Sales-Invoice as per DayWise",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Sales-Invoice as per DayWise')

# %%
# get the sales for Hours and plot a graph
Hours_sale = pd.DataFrame(df_9.groupby('Hours')['InvoiceNo'].nunique())
Hours_sale = Hours_sale.sort_values('InvoiceNo',ascending=False)
Hours_sale.head()
# Out:
#        InvoiceNo
# Hours
# 12          3130
# 13          2636
# 11          2277
# 14          2274
# 10          2226

# %%
plt.figure(figsize=(13,7))
sns.barplot(x=Hours_sale.index, y="InvoiceNo", data=Hours_sale)
plt.grid()
plt.title("Sales-Invoice as per Hourly",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Sales-Invoice as per Hourly')

# %% [markdown]
#  # Conclusion : Insights
#
# 1. Nov 2011 has highest orders.
# 2. Thursday has highest sales in a week.
# 3. There are no order in Saturday.
# 4. Sales starts from 7am to 8pm with highest during noon.

# %%
df_9.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
#
#         Date  Year Year-Month        Day Hours
# 0 2010-12-01  2010     201012  Wednesday    08
# ...

# %%
#find outliers
sns.boxplot(df_9["Quantity"],orient="v")

# %%
df_9[df_9["Quantity"]>60000]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61619     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice CustomerID         Country    Amount  \
# 61619  2011-01-18 10:01:00       1.04      12346  United Kingdom   77183.6
# 540421 2011-12-09 09:15:00       2.08      16446  United Kingdom  168469.6
#
#              Date  Year Year-Month      Day Hours
# 61619  2011-01-18  2011     201101  Tuesday    10
# 540421 2011-12-09  2011     201112   Friday    09

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="Date",y="Quantity",data=df_9)
plt.grid()

# %%
# another way to find outliers
plt.figure(figsize=(15,7))
# bo is a marker color and type
plt.plot(df_9["Date"],df_9["Quantity"],"bo",markersize=5)
plt.xlabel("Timestamp",fontsize=13)
plt.ylabel("Quantity", fontsize=13)
plt.title("Quantity graph as per Date and find Outliers", fontsize=15,color="green")
plt.grid()

# %%
#here we drop Outliers but not always its depends on client
df_10 = df_9[df_9["Quantity"]<10000]

# %%
df_10.shape
# Out:
# (392690, 14)

# %%
df_9.shape
# Out:
# (392692, 14)

# %%
plt.figure(figsize=(15,7))
plt.plot(df_10["Date"],df_10["Quantity"],"bo",markersize=5)
plt.xlabel("Timestamp",fontsize=13)
plt.ylabel("Quantity", fontsize=13)
plt.title("Quantity graph as per Date and find Outliers", fontsize=15,color="green")
plt.grid()

# %% [markdown]
# # Insights
# 1. There are some Outliers in the Quantity column.
# 2.  after removing outliers brings data visual more resonable.

# %%
#find the total count of days avail in the data
df_10["Date"].nunique()
  #also try
#show all unique list rows
#df_10["Date"].unique()
#show only 0 index Date
#df_10["Date"].unique()[0]
# Out:
# 305

# %%
# how many dates in the data 
df_10["Date"].max()-df_10["Date"].min()
# Out:
# Timedelta('373 days 00:00:00')

# %%
df_11=df_10.copy()

# %%
df_11["Date_diff"] = df_11["Date"].diff().dt.days
df_11["Date_diff"] = df_11["Date_diff"].fillna(0).astype(int)

# %%
df_11.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
#
#         Date  Year Year-Month        Day Hours  Date_diff
# 0 2010-12-01  2010     201012  Wednesday    08          0
# ...

# %%
#Date Diff
df_11["Date_diff"].unique()
# Out:
# array([ 0,  1,  2, 12,  5,  3])

# %%
#date diff DIstribution
df_11["Date_diff"].value_counts()
# Out:
# 0     392386
# 1        249
# 2         52
# 12         1
# 5          1
# 3          1
# Name: Date_diff, dtype: int64

# %%
df_11[df_11["Date_diff"]==12]
# Out:
#       InvoiceNo StockCode              Description  Quantity  \
# 42481    539993     22386  JUMBO BAG PINK POLKADOT        10
#
#               InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 42481 2011-01-04 10:00:00       1.95      13313  United Kingdom    19.5
#
#             Date  Year Year-Month      Day Hours  Date_diff
# 42481 2011-01-04  2011     201101  Tuesday    10         12

# %%
#see two last row date diff is 12
#df_11.loc[:42481]
df_11.loc[42452:42481]
# Out:
#       InvoiceNo StockCode              Description  Quantity  \
# 42452    539988    47559B      TEA TIME OVEN GLOVE         2
# 42481    539993     22386  JUMBO BAG PINK POLKADOT        10
#
#               InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 42452 2010-12-23 16:06:00       1.25      18116  United Kingdom     2.5
# 42481 2011-01-04 10:00:00       1.95      13313  United Kingdom    19.5
#
#             Date  Year Year-Month       Day Hours  Date_diff
# 42452 2010-12-23  2010     201012  Thursday    16          0
# 42481 2011-01-04  2011     201101   Tuesday    10         12

# %% [markdown]
# # Insights
# 1. no data from 12/23/2010 to 01/04/2011.
# 2. seems christmas and new year time.
# 3. no data collection these days.

# %%
#did the same as above with marker
plt.figure(figsize=(18,4))
plt.plot(df_11["InvoiceDate"],df_11["Quantity"])
plt.grid()

# %%
# cross check with my original data
plt.figure(figsize=(18,4))
plt.plot(df["InvoiceDate"],df["Quantity"])
plt.grid()

# %%
#find the missing country from original row data
country_all_df = df["Country"].unique()
#to list, create a list. by default array occur.
country_all_df_11 = df_11["Country"].unique().tolist()
set(country_all_df) - set(country_all_df_11)
# Out:
# {'Hong Kong'}

# %%
df[df["Country"]=="Hong Kong"]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 69623     541975     22620          4 TRADITIONAL SPINNING TOPS        60
# 69624     541975    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA         6
# 69625     541975    85183A   CHARLIE & LOLA WASTEPAPER BIN BLUE         6
# 69626     541975     16236                 KITTY PENCIL ERASERS        28
# 69627     541975     21058               PARTY INVITES WOODLAND        12
# ...          ...       ...                                  ...       ...
# 423776    573154     22452         MEASURING TAPE BABUSHKA PINK        30
# 423777    573154     22492              MINI PAINT SET VINTAGE         36
# 423778    573154     23328   SET 6 SCHOOL MILK BOTTLES IN CRATE         8
# 465423   C576233         M                               Manual        -1
# 465424    576234         M                               Manual         1
#
#                InvoiceDate  UnitPrice  CustomerID    Country
# ...

# %%
df_11.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
#
#         Date  Year Year-Month        Day Hours  Date_diff
# 0 2010-12-01  2010     201012  Wednesday    08          0
# ...

# %%
top_cust = pd.DataFrame(df_11.groupby(["CustomerID"])["Amount"].sum())
top_cust = top_cust.sort_values("Amount",ascending=False)
top_cust.head()
# Out:
#                Amount
# CustomerID
# 14646       280206.02
# 18102       259657.30
# 17450       194390.79
# 14911       143711.17
# 12415       124914.53

# %%
top_cust = pd.DataFrame(df_11.groupby(["CustomerID"])["Quantity"].sum())
top_cust = top_cust.sort_values("Quantity",ascending=False)
top_cust.head()
# Out:
#             Quantity
# CustomerID
# 14646         196915
# 14911          80240
# 12415          77374
# 17450          69973
# 17511          64549

# %%
df_11["Week"] = df_11["InvoiceDate"].dt.strftime('%W')
df_11["Hours"] = df_11["InvoiceDate"].dt.strftime('%H')

# %%
df_11.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
#
#         Date  Year Year-Month        Day Hours  Date_diff Week
# 0 2010-12-01  2010     201012  Wednesday    08          0   48
# ...

# %%
df_11["Amount"].sum()
# Out:
# 8633430.943999998

# %%
df_11[df_11["StockCode"]=="22423"]
# Out:
#        InvoiceNo StockCode               Description  Quantity  \
# 880       536477     22423  REGENCY CAKESTAND 3 TIER        16
# 936       536502     22423  REGENCY CAKESTAND 3 TIER         2
# 1092      536525     22423  REGENCY CAKESTAND 3 TIER         2
# 1155      536528     22423  REGENCY CAKESTAND 3 TIER         1
# 1197      536530     22423  REGENCY CAKESTAND 3 TIER         1
# ...          ...       ...                       ...       ...
# 538094    581397     22423  REGENCY CAKESTAND 3 TIER         3
# 538944    581425     22423  REGENCY CAKESTAND 3 TIER         1
# 539891    581449     22423  REGENCY CAKESTAND 3 TIER         1
# 540216    581472     22423  REGENCY CAKESTAND 3 TIER         2
# 541231    581495     22423  REGENCY CAKESTAND 3 TIER        10
#
#                InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 880    2010-12-01 12:27:00      10.95      16210  United Kingdom  175.20
# ...

# %%
# using this code only single change "ID" , make different StockCode analysis. can try on POST
# 1st select a stockCode as ID
ID = "22423"
#ID = "POST"
#data of that id is in Stock1
Stock_1 = df_11[df_11["StockCode"]==ID]
# a column and can be change for different column analysis
col = "Quantity"

# %%
plt.figure(figsize=(18,7))
# x axis is InvoiceDate and y is Quantity and all the data belong to id 22423
plt.plot(Stock_1["InvoiceDate"],Stock_1[col],'o-')
plt.xlabel("Timestamp",fontsize=13)
plt.ylabel(col,fontsize=13)
plt.title("Trend of Product: " +ID, fontsize=15)
plt.grid()

# %%
# in the below code as same as above. in this we create a use define funtion, the only difference. 

def time_series(data, x, y, ID):
    Stock_1 = data[data["StockCode"] == ID]

    plt.figure(figsize=(18,7))
    plt.plot(Stock_1[x],Stock_1[y],"o-",markersize=5)
    plt.xlabel("Timestamp",fontsize=13)
    plt.ylabel(y,fontsize=13)
    plt.title(y+ "trend of product " +ID, fontsize=13)
    plt.grid()

# %%
# using the above function
time_series(data=df_11, x="InvoiceDate", y="Quantity", ID="POST")

# %%
# change the data. df_3 have -ve values.
time_series(data=df_3, x="InvoiceDate", y="Quantity", ID="POST")

# %%
# pivot table compare by columns like as groupby
pd.pivot_table(data=df_11, values="UnitPrice", index="StockCode", columns = "Country", aggfunc='mean').fillna(0)
# Out:
# Country    Australia    Austria  Bahrain   Belgium  Brazil  Canada  \
# StockCode
# 10002            0.0   0.000000      0.0   0.00000     0.0    0.00
# 10080            0.0   0.000000      0.0   0.00000     0.0    0.00
# 10120            0.0   0.000000      0.0   0.00000     0.0    0.00
# 10123C           0.0   0.000000      0.0   0.00000     0.0    0.00
# 10124A           0.0   0.000000      0.0   0.00000     0.0    0.00
# ...              ...        ...      ...       ...     ...     ...
# C2               0.0   0.000000      0.0   0.00000     0.0    0.00
# DOT              0.0   0.000000      0.0   0.00000     0.0    0.00
# M                0.0   0.000000      0.0   0.00000     0.0    0.00
# PADS             0.0   0.000000      0.0   0.00000     0.0    0.00
# POST           350.0  39.142857      0.0  15.46875     0.0  550.94
#
# Country    Channel Islands  Cyprus  Czech Republic    Denmark  ...  RSA  \
# StockCode                                                      ...
# ...

# %%
# find top 5 and add a column
top_cust = pd.DataFrame(df_11.groupby(["CustomerID"])["Quantity"].sum())
top_cust["UnitPrice_Mean"] = df_11.groupby("CustomerID")["UnitPrice"].mean()
top_cust.head()
# Out:
#             Quantity  UnitPrice_Mean
# CustomerID
# 12347           2458        2.644011
# 12348           2341        5.764839
# 12349            631        8.289041
# 12350            197        3.841176
# 12352            536       15.930706
